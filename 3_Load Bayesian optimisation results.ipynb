# %%
import os
import numpy as np
import pandas as pd
import datetime

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt

# %%
hparam_values = {"conv_f": 3,
                "conv1_out_depth": 10,
                "conv2_out_depth": 16,
                "fc1_out": 120,
                "fc2_out": 84,
                "lr": -2,
                "momentum": -0.05} #hparams for the first iteration, to help with search

# %% [markdown]
# # Load optimisation results

# %%
query_arr = []
observation_arr = []

stored_results = [item for item in os.listdir("./optimisation_results/")]
time_stamps = [float("".join(item.split("_")[:2])) for item in stored_results] 
last_result = stored_results[np.argmax(time_stamps)]
df = pd.read_pickle("./optimisation_results/"+last_result)

for index, row in df.iterrows():
    query_i_dict = row.drop("acc").to_dict()
    query_i_arr = list(query_i_dict.values())
    observation_i = df.loc[index, "acc"]

    #optimizer.register(params = query_i_dict, target = observation_i)

    query_arr.append(query_i_arr)
    observation_arr.append(observation_i)

    
print(last_result)
df_optimisation = pd.DataFrame(data = query_arr, columns = hparam_values.keys())
df_optimisation["acc"] = observation_arr

cols = df_optimisation.columns.values[:5]
for col in cols:
    df_optimisation[col] = round(df_optimisation[col])
# Out:
# 20221128_113957_results

# %%
df_optimisation
# Out:
#       conv_f  conv1_out_depth  conv2_out_depth  fc1_out  fc2_out        lr  \
# 0        3.0             10.0             16.0    120.0     84.0 -2.000000
# 1        6.0             10.0             15.0     52.0    190.0  0.000412
# 2        4.0             13.0             10.0    114.0     61.0  0.000195
# 3        2.0             14.0              6.0    129.0     54.0  0.003826
# 4        2.0              1.0              3.0     86.0     67.0  0.043806
# ...      ...              ...              ...      ...      ...       ...
# 1437    17.0             12.0              7.0    155.0     74.0 -1.013305
# 1438    17.0             11.0              6.0    189.0    166.0 -2.311756
# 1439    15.0             15.0              7.0    152.0     73.0 -1.422262
# 1440    18.0              8.0              7.0    187.0     81.0 -2.504928
# 1441    18.0             19.0              6.0    111.0     59.0 -1.156563
#
#       momentum    acc
# 0    -0.050000  74.95
# 1     0.001972  10.00
# 2     0.051410  10.55
# 3     0.000383  10.55
# 4     0.006345  11.50
# ...        ...    ...
# 1437 -2.457042  96.05
# 1438 -1.396908  11.50
# 1439 -2.390712  56.65
# 1440 -3.360234  10.00
# 1441 -1.618561  95.80
#
# [1442 rows x 8 columns]

# %% [markdown]
# # Visualise optimisation progression

# %% [markdown]
# For each iteration of the bayesian optimisation, plot the best performing configuration found so far.

# %%
df_optimisation["best"] = 0
for i in range(len(df_optimisation.acc)):
    df_optimisation.best[i] = df_optimisation.acc[:i+1].max()
    
df_optimisation.best.plot()
plt.ylabel("Model accuracy on test set")
plt.xlabel("Iteration no.")
# Out:
# /var/folders/dm/nwgq0gln70ggf849zsbll9s00000gn/T/ipykernel_24617/111875265.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_optimisation.best[i] = df_optimisation.acc[:i+1].max()
# Text(0.5, 0, 'Iteration no.')

# %% [markdown]
# ## Show some of the top performing CNN configurations

# %%
df_optimisation.sort_values(by = "acc", ascending=False, inplace=True)
df_optimisation.head(30)
# Out:
#       conv_f  conv1_out_depth  conv2_out_depth  fc1_out  fc2_out        lr  \
# 1395    19.0              6.0              9.0    187.0     82.0 -1.067793
# 823     13.0             12.0              9.0    187.0    160.0 -1.283457
# 592     19.0             16.0              9.0     48.0     95.0 -1.221901
# 1101    15.0             16.0              9.0    184.0    165.0 -1.232466
# 1076    14.0             14.0              9.0    191.0    117.0 -1.292019
# 1292    15.0             13.0              9.0    190.0    159.0 -1.170784
# 1332    15.0             12.0              7.0    188.0    162.0 -1.000000
# 974     19.0             15.0              6.0    189.0    165.0 -1.049124
# 574     15.0             13.0              7.0    185.0    165.0 -1.039322
# 1400     7.0             16.0              7.0    166.0    101.0 -1.000000
# 1273    16.0             11.0              5.0    150.0     73.0 -1.094684
# 1272    17.0             13.0              5.0    188.0    167.0 -1.030127
# 1014    12.0              9.0              9.0     19.0    136.0 -1.052221
# 859      7.0              6.0              9.0    172.0    139.0 -1.033048
# 789     17.0             13.0              5.0    186.0    166.0 -1.025689
# 1000    10.0             12.0              5.0      5.0    151.0 -1.253695
# 666      6.0             12.0              7.0     68.0    185.0 -1.006332
# 1139    18.0             15.0              5.0     34.0     71.0 -1.188393
# 1437    17.0             12.0              7.0    155.0     74.0 -1.013305
# 1441    18.0             19.0              6.0    111.0     59.0 -1.156563
# 523      8.0              5.0              9.0    170.0    139.0 -1.301626
# 367     15.0             13.0              8.0    186.0    161.0 -1.000000
# 508      9.0              9.0              5.0     64.0    196.0 -1.123225
# 862     18.0              3.0              7.0    112.0    163.0 -1.000000
# 824      6.0             12.0              7.0     69.0    185.0 -1.011348
# 1077    19.0             18.0              5.0    187.0    167.0 -1.319459
# 953     18.0             15.0              5.0     34.0     70.0 -1.111195
# 1374    16.0             13.0              6.0    190.0    117.0 -1.130460
# 492     18.0              5.0              8.0    185.0     83.0 -1.207783
# 1274    19.0             18.0              5.0    187.0    167.0 -1.250317
#
#       momentum    acc   best
# 1395 -3.298958  99.40  99.40
# 823  -3.622337  99.15  99.15
# 592  -3.551631  98.90  98.90
# 1101 -2.716221  98.80  99.15
# 1076 -1.079094  98.55  99.15
# 1292 -2.039232  98.40  99.15
# 1332 -1.862660  97.95  99.15
# 974  -3.348146  97.65  99.15
# 574  -2.458057  97.60  97.60
# 1400 -2.325208  97.20  99.40
# 1273 -2.410763  97.20  99.15
# 1272 -1.846348  97.15  99.15
# 1014 -3.110998  96.95  99.15
# 859  -1.792187  96.90  99.15
# 789  -2.177878  96.85  98.90
# 1000 -2.004862  96.20  99.15
# 666  -1.337735  96.20  98.90
# 1139 -1.135865  96.15  99.15
# 1437 -2.457042  96.05  99.40
# 1441 -1.618561  95.80  99.40
# 523  -3.789245  95.60  95.60
# 367  -3.130475  95.50  95.50
# 508  -1.240734  95.45  95.50
# 862  -2.901374  95.30  99.15
# 824  -1.354748  95.30  99.15
# 1077 -3.648855  95.25  99.15
# 953  -1.223368  95.15  99.15
# 1374 -3.557221  95.00  99.15
# 492  -1.624526  94.50  95.50
# 1274 -3.486523  94.25  99.15

# %% [markdown]
# ### PCA analysis of optimisation

# %%
X = df_optimisation.drop(columns = ["acc", "best"]).transpose().to_numpy()
y = df_optimisation.acc.to_numpy()

z = StandardScaler().fit_transform(np.transpose(X))
pca = PCA(n_components=3)
pca_arr = pca.fit_transform(z)

# %%
plt.figure(figsize = (7,7))
plt.scatter(pca_arr[:, 0], pca_arr[:, 1], c=y)
plt.colorbar()
plt.xlabel("PCA Comp 1", )
plt.ylabel("PCA Comp 2", )
plt.show()

# %%
fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(projection='3d')
ax.scatter(pca_arr[:,0], pca_arr[:,1], pca_arr[:,2], c=y)
plt.show()

# %% [markdown]
# ### PCA components

# %%
pca.components_[0]
# Out:
# array([-0.2218213 ,  0.26123479, -0.52817497, -0.55481093, -0.48061263,
#        -0.24174529,  0.07961434])

# %%
pca.components_[1]
